# %%
from scipy.stats import chisquare

# Restaurant counts
observed = [140, 8]   # Online order, Table booking

# Expected equal distribution
expected = [74, 74]

chi_stat, p_value = chisquare(observed, expected)

print("Chi-Square Statistic:", chi_stat)
print("P-Value:", p_value)

if p_value < 0.05:
    print("Reject Null Hypothesis")
    print("Online ordering is significantly more preferred.")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Chi-Square Statistic: 117.72972972972973
# P-Value: 1.9869975209940292e-27
# Reject Null Hypothesis
# Online ordering is significantly more preferred.
